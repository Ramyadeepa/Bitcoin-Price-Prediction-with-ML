# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/ramya/Documents/Asterisc Intern/Data Science Intern Projects/Bitcoin Price Prediction with ML/TASK05-20230930T173552Z-001/TASK05/bitcoin.csv')
df.head(20)
# Out:
#          Date        Price
# 0   5/23/2019  7881.846680
# 1   5/24/2019  7987.371582
# 2   5/25/2019  8052.543945
# 3   5/26/2019  8673.215820
# 4   5/27/2019  8805.778320
# 5   5/28/2019  8719.961914
# 6   5/29/2019  8659.487305
# 7   5/30/2019  8319.472656
# 8   5/31/2019  8574.501953
# 9    6/1/2019  8564.016602
# 10   6/2/2019  8742.958008
# 11   6/3/2019  8208.995117
# 12   6/4/2019  7707.770996
# 13   6/5/2019  7824.231445
# 14   6/6/2019  7822.023438
# 15   6/7/2019  8043.951172
# 16   6/8/2019  7954.127930
# 17   6/9/2019  7688.077148
# 18  6/10/2019  8000.329590
# 19  6/11/2019  7927.714355

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', inplace=True)
df.head(20)
# Out:
#          Date        Price
# 0  2019-05-23  7881.846680
# 1  2019-05-24  7987.371582
# 2  2019-05-25  8052.543945
# 3  2019-05-26  8673.215820
# 4  2019-05-27  8805.778320
# 5  2019-05-28  8719.961914
# 6  2019-05-29  8659.487305
# 7  2019-05-30  8319.472656
# 8  2019-05-31  8574.501953
# 9  2019-06-01  8564.016602
# 10 2019-06-02  8742.958008
# 11 2019-06-03  8208.995117
# 12 2019-06-04  7707.770996
# 13 2019-06-05  7824.231445
# 14 2019-06-06  7822.023438
# 15 2019-06-07  8043.951172
# 16 2019-06-08  7954.127930
# 17 2019-06-09  7688.077148
# 18 2019-06-10  8000.329590
# 19 2019-06-11  7927.714355

# %%
features = df[['Price']]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, df['Price'], test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 0.0
# Mean Absolute Error: 0.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price'], label='Actual Price', color='b')
plt.plot(X_test.index, y_pred, label='Predicted Price', color='r')
plt.xlabel('Date')
plt.ylabel('Bitcoin Price')
plt.legend()
plt.title('Bitcoin Price Prediction')
plt.show()

# %%
window_size = 5
rolling_mean = df['Price'].rolling(window=window_size).mean()
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price'], label='Actual Price', color='b')
plt.plot(df['Date'], rolling_mean, label=f'Rolling Mean ({window_size} days)', color='r')
plt.xlabel('Date')
plt.ylabel('Bitcoin Price')
plt.legend()
plt.title('Bitcoin Price and Rolling Mean')
plt.show()
